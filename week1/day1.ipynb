# %%
from scraper import fetch_website_contents
from langchain_ollama import ChatOllama
from IPython.display import Markdown, display
# Out:
# /Users/prasanthravula/LLM_ENGINEERING_PROJECTS/.venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
# ed = fetch_website_contents("https://edwarddonner.com") #("https://en.wikipedia.org/wiki/Artificial_intelligence")


# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish.'
system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# Define our user prompt
user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.
"""

# See how this function creates exactly the format above
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]
    
# Try this out, and then try for a few more websites
# messages_for(ed)

def summarize(url):
    website = fetch_website_contents(url)
    llm = ChatOllama(model="kimi-k2.5:cloud")
    response = llm.invoke(messages_for(website))
    return response.content

# %%
summarize("https://edwarddonner.com")
# Out:
# 'Edward Donner is what happens when a Hacker News comment section achieves sentience and buys a domain. By day, he\'s the CTO of Nebula.io—applying AI to help people find their "reason for being" (because apparently traditional therapy doesn\'t scale)—and by night, he\'s an "amateur" electronic musician, presumably scoring the existential dread of his former startup untapt being acquired in 2021. After his friends staged a much-needed intervention against his impromptu LLM lectures, he took his rambling to Udemy, where 400,000 students across 190 countries now suffer through his courses voluntarily. He freely admits to nodding sagely at things he only half understands on Hacker News, but now charges for the privilege.\n\n**Latest Deployments from the Content Mines:**\n- **February 17, 2026:** *AI Coder: Vibe Coder to Agentic Engineer* – Teaching you to "vibe code" before the concept inevitably dies in a fire, apparently from the future.\n- **January 4, 2026:** *AI Builder with n8n* – Because if you\'re going to automate yourself out of relevance, you might as well do it with no-code visual workflows.\n- **September 15, 2025:** *AI Engineering MLOps Track* – Finally, instructions on deploying AI to production, where it can hallucinate at scale.\n- **May 28, 2025:** *Which order to take the AI courses?* – A meta-course for the chronologically confused, presumably necessary because the other resources exist outside linear time.'

# %%
# A function to display this nicely in the output, using markdown
def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

display_summary("https://www.linkedin.com/jobs/")
# Out:
# **LinkedIn: Where Professional Dreams Go to Click "Agree & Join"**
#
# This is essentially a very polite bouncer standing between you and millions of jobs. The site desperately wants you to know it's "better on the app" (because apparently checking your unemployment status needs to be mobile-first) and offers a delightful buffet of career categories from "Engineering" to "Military and Protective Services"—you know, for when your midlife crisis needs options.
#
# The pièce de résistance? **Games.** Yes, because nothing says "serious career networking" like pausing your job hunt to play *Mini Sudoku* or *Queens*. Nothing breeds professional success quite like procrastinating with "quick daily games" while your student loans compound.
#
# Also included: the "Open to Work" feature (translation: desperate but with a green banner), endless prompts to "reconnect with your network" (translation: bother people you met once in 2014), and the standard LinkedIn promise that "conversations today could lead to opportunity tomorrow"—or at least a notification spam from a recruiter offering a "exciting unpaid internship" in another state.
